# %%
import pandas as pd

# %%
import numpy as np

countries = ['India','France','England']                                   # Creating two lists containing name of the country and its capital
capitals = ['New Delhi','Paris','London']                                      
arr = np.array(capitals)                                                   # Making an array with the list capitals
dicts = {'a':10, 'b':20, 'c':30, 'd':40, 'e':50, 'f':60, 'g':70, 'h':80}   # Defining a dictionary

# %%
dat = pd.Series(data = capitals, index = countries)                              # Modifying series by adding index

# %%
dir(dat)
# Out:
# ['England',
#  'France',
#  'India',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
# ...

# %%
dat
# Out:
# India      New Delhi
# France         Paris
# England       London
# dtype: object

# %%
np.NaN
# Out:
# nan

# %%
df =pd.DataFrame({'id':[1,2,3], 'count':[np.NaN,2,4]})

# %%
df.rename(columns={'count':'count_id'})
# Out:
#    id  count_id
# 0   1         1
# 1   2         2
# 2   3         4

# %%
print(df.columns)
# Out:
# Index(['id', 'count'], dtype='object')

# %%
df.loc[:,df.notnull().all()]
# Out:
#    id
# 0   1
# 1   2
# 2   3

# %%
np.__version__
# Out:
# '1.14.3'

# %%
np.show_config()
# Out:
# mkl_info:
#     libraries = ['mkl_rt']
#     library_dirs = ['C:/Users/RaviRohanChaitu/Anaconda3\\Library\\lib']
#     define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#     include_dirs = ['C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2016.4.246\\windows\\mkl', 'C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2016.4.246\\windows\\mkl\\include', 'C:\\Program Files (x86)\\IntelSWTools\\compilers_and_libraries_2016.4.246\\windows\\mkl\\lib', 'C:/Users/RaviRohanChaitu/Anaconda3\\Library\\include']
# blas_mkl_info:
#     libraries = ['mkl_rt']
#     library_dirs = ['C:/Users/RaviRohanChaitu/Anaconda3\\Library\\lib']
#     define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
# ...

# %%
df
# Out:
#    id  count
# 0   1    NaN
# 1   2    2.0
# 2   3    4.0

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
train = pd.DataFrame({'id':[1,2,3], 'feature':[['A','B','C'], ['A','D','E'],['B','D',"F"]]})

# %%
train
# Out:
#    id    feature
# 0   1  [A, B, C]
# 1   2  [A, D, E]
# 2   3  [B, D, F]

# %%
train['feature_t'] = train['feature'].apply(lambda x: "".join(x))

# %%
print (train['feature_t'])
# Out:
# 0    ABC
# 1    ADE
# 2    BDF
# Name: feature_t, dtype: object

# %%
import numpy as np

# %%
import numpy.linalg

# %%
A = np.mat([[2,1], [1,2]])

# %%
B = numpy.linalg.inv(A)

# %%
A*B
# Out:
# matrix([[1., 0.],
#         [0., 1.]])

# %%
print (A.resize(1,4))
print(A)
# Out:
# None
# [[2 1 1 2]]

# %%
print (A.reshape(1,4))
print(A)
# Out:
# [[2 1 1 2]]
# [[2 1 1 2]]
